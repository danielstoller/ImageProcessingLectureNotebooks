# %% [markdown]
# # ARUCU Markers
#
# These are small icons similar to QR codes.  These are low bit symbols.
#
# Here is a website that allows you to generate them https://chev.me/arucogen/

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('Arucu_Markers_example.png')
plt.imshow(img)

# %%
dictionary=cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_1000)

# %%
corners,ids,rejected = cv2.aruco.detectMarkers(img,dictionary)

# %%
for idx in range(0,ids.shape[0]):
    thiscorner=corners[idx][0]
    pos=np.uint16(thiscorner.mean(axis=0))
    cv2.putText(img,f"{ids[idx]}",pos,cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),2)

# %%
plt.imshow(img)
